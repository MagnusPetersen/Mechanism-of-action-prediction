# %%
import os
import gc
import random
import math
import time
import numpy as np
import pandas as pd

import category_encoders as ce
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from sklearn import preprocessing, decomposition
from sklearn.decomposition import KernelPCA

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torch.optim as optim
import torch.nn.functional as F
import torchvision
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor
from pytorch_tabnet.metrics import Metric
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#Hyperparameters
#PCA
pca_num = 20
#Autoencoder
autoencoder_batch_size = 100
autoenecoder_latents = 40 
autoencoder_val_size = 400
autoencoder_epochs = 60
autoencoder_learning_rate = 0.005
autoencoder_hidden_size_1 = 500
autoencoder_hidden_size_2 = 200
autoencoder_hidden_size_3 = 150
#TabNet
n_folds = 10
tabnet_batch_size = 100
tabnet_learning_rate = 2e-2
tabnet_weight_decay = 1e-5
decision_layer_size = 32
mask_attention_layer_size = 32
#Constants
feature_size = 874
lable_size = 206

# %%
train_features = pd.read_csv('Data/train_features.csv')
train_targets_scored = pd.read_csv('Data/train_targets_scored.csv')
train_targets_nonscored = pd.read_csv('Data/train_targets_nonscored.csv')
test_features = pd.read_csv('Data/test_features.csv')
submission = pd.read_csv('Data/sample_submission.csv')

# %%
train = train_features.merge(train_targets_scored, on='sig_id')
print(train_features.shape, test_features.shape)
train = train[train['cp_type']!='ctl_vehicle'].reset_index(drop=True)
test = test_features
print(train.shape, test.shape)
# Out:
# (23814, 876) (3982, 876)
# (21948, 1082) (3982, 876)

# %%
train['cp_time'] = train['cp_time'].map({24: -1, 48: 0, 72: 1})
train['cp_dose'] = train['cp_dose'].map({'D1': -0.5, 'D2': 0.5})

test['cp_time'] = test['cp_time'].map({24: -1, 48: 0, 72: 1})
test['cp_dose'] = test['cp_dose'].map({'D1': -0.5, 'D2': 0.5})

# %%
train = train.to_numpy()
test = test.to_numpy()
dist_len = 99 + 771
for d in range(dist_len):
    train[::, 4+d]  = preprocessing.scale(train[::, 4+d])
    test[::, 4+d]  = preprocessing.scale(test[::, 4+d])
train = train[::, 2:].astype('float64') 
test = test[::, 2:].astype('float64')

# %% [markdown]
# Feature Engineering

# %% [markdown]
# Kernel PCA

# %%
transformer = KernelPCA(n_components=pca_num, kernel='linear')
X_transformed = transformer.fit_transform(train[::, :feature_size])
test_transformed = transformer.transform(test)

# %% [markdown]
# Autoencoder

# %%
mse = nn.MSELoss()

traningy = train[autoencoder_val_size:, :feature_size]
valdationy = train[:autoencoder_val_size, :feature_size]

transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])

train_loader_ae = torch.utils.data.DataLoader(
    traningy, batch_size=autoencoder_batch_size, shuffle=False, pin_memory=True)

test_loader_ae = torch.utils.data.DataLoader(
    valdationy, batch_size=autoencoder_batch_size, shuffle=False, pin_memory=True)

class AE(nn.Module):
    def __init__(self, **kwargs):
        super().__init__()
        self.encoder_il = nn.Linear(feature_size, autoencoder_hidden_size_1)
        self.bnorm1 = nn.BatchNorm1d(num_features=autoencoder_hidden_size_1)
        self.encoder_hl1 = nn.Linear(autoencoder_hidden_size_1, autoencoder_hidden_size_2)
        self.bnorm2 = nn.BatchNorm1d(num_features=autoencoder_hidden_size_2)
        self.encoder_hl2 = nn.Linear(autoencoder_hidden_size_2, autoencoder_hidden_size_3)
        self.bnorm3 = nn.BatchNorm1d(num_features=autoencoder_hidden_size_3)
        self.encoder_ol = nn.Linear(autoencoder_hidden_size_3, autoenecoder_latents)
        
        self.bnorm4 = nn.BatchNorm1d(num_features=autoenecoder_latents)
        self.decoder_il = nn.Linear(autoenecoder_latents, autoencoder_hidden_size_3)
        self.bnorm5 = nn.BatchNorm1d(num_features=autoencoder_hidden_size_3)
        self.decoder_hl1 = nn.Linear(autoencoder_hidden_size_3, autoencoder_hidden_size_2)
        self.bnorm6 = nn.BatchNorm1d(num_features=autoencoder_hidden_size_2)
        self.decoder_hl2 = nn.Linear(autoencoder_hidden_size_2, autoencoder_hidden_size_1)
        self.bnorm7 = nn.BatchNorm1d(num_features=autoencoder_hidden_size_1)
        self.decoder_ol = nn.Linear(autoencoder_hidden_size_1, feature_size)
        
        self.elu = nn.ELU()
        
    def forward_encoder(self, x):
        x = self.encoder_il(x)
        x = self.elu(x)
        x = self.bnorm1(x)
        x = self.encoder_hl1(x)
        x = self.elu(x)
        x = self.bnorm2(x)
        x = self.encoder_hl2(x)
        x = self.elu(x)
        x = self.bnorm3(x)
        emb = self.encoder_ol(x)
        return emb
    
    def forward_decoder(self, emb):    
        x = self.bnorm4(emb)
        x = self.decoder_il(x)
        x = self.elu(x)
        x = self.bnorm5(x)
        x = self.decoder_hl1(x)
        x = self.elu(x)
        x = self.bnorm6(x)
        x = self.decoder_hl2(x)
        x = self.elu(x)
        x = self.bnorm7(x)
        x = self.decoder_ol(x)
        return x
    
model_ae = AE().to(device)
optimizer_ae = optim.Adam(model_ae.parameters(), lr=autoencoder_learning_rate)

epoch_list = []
val_list = []

for epoch in range(autoencoder_epochs):
    train_loss_en = 0
    train_loss_de = 0
    loss = 0
    
    for x in train_loader_ae:
        
        x = x.to(device)
        optimizer_ae.zero_grad()
        x = x.view((-1, feature_size))
        emb = model_ae.forward_encoder(x.float())
        rec = model_ae.forward_decoder(emb)
        # compute training reconstruction loss
        train_loss = mse(rec.double(), x)

        # compute accumulated gradients
        train_loss.backward()

        # perform parameter update based on current gradients
        optimizer_ae.step()
 
        # add the mini-batch training loss to epoch loss
        loss += train_loss_en

    if (epoch % 1) == 0:
        val_loss_en = 0 
        val_loss_de = 0
        
        for x in test_loader_ae:
            x = x.to(device)
            
            x = x.view((-1, feature_size))
            emb = model_ae.forward_encoder(x.float())
            rec = model_ae.forward_decoder(emb)
            # compute training reconstruction loss
            val_loss = mse(rec.double(), x)
            
        val_loss = val_loss.cpu().detach().numpy()
        val_list.append(val_loss)
       
        epoch_list.append(epoch)
        
        print("Validation: epoch : {}/{}, loss = {:.4f}".format(epoch+1, autoencoder_epochs, val_loss))

# %%
model_ae.eval()
enc_ae = np.empty(shape = (train.shape[0], autoenecoder_latents))
for i in range(enc_ae.shape[0]):
    x = torch.from_numpy(np.asarray(train[i, :feature_size])).to(device).float()
    x = x.view(-1, feature_size)
    x = model_ae.forward_encoder(x)
    enc_ae[i, ::] = np.reshape(x.cpu().detach().numpy(), (autoenecoder_latents))
    
enc_ae_test = np.empty(shape = (test.shape[0], autoenecoder_latents))
for i in range(enc_ae_test.shape[0]):
    x = torch.from_numpy(np.asarray(test[i, :feature_size])).to(device).float()
    x = x.view(-1, feature_size)
    x = model_ae.forward_encoder(x)
    enc_ae_test[i, ::] = np.reshape(x.cpu().detach().numpy(), (autoenecoder_latents))

# %%
train_d = np.concatenate((train[::, :feature_size], X_transformed, enc_ae), axis = 1)

lables_train = train[::, feature_size:]

dataset = torch.utils.data.TensorDataset( torch.Tensor(train_d), torch.Tensor(lables_train) )

transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])

train_loader = torch.utils.data.DataLoader(
    dataset, batch_size=tabnet_batch_size, shuffle=True, pin_memory=True)

# %%
train_aug = np.concatenate((test[::, :feature_size], test_transformed, enc_ae_test), axis = 1)
pred_loader = torch.utils.data.DataLoader(train_aug, batch_size=tabnet_batch_size, shuffle=True, pin_memory=True)

# %% [markdown]
# Tabnet

# %%
class LogitsLogLoss(Metric):

    def __init__(self):
        self._name = "val_loss"
        self._maximize = False

    def __call__(self, y_true, y_pred):

        logits = 1 / (1 + np.exp(-y_pred))
        aux = (1 - y_true) * np.log(1 - logits + 1e-15) + y_true * np.log(logits + 1e-15)
        return np.mean(-aux)

# %%
NB_SPLITS = n_folds
mskf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, random_state = 0, shuffle = True)
pred_encode = np.empty(shape = (NB_SPLITS, test.shape[0], lable_shape))

for fold_nb, (train_idx, val_idx) in enumerate(mskf.split(train_d, lables_train)):
    print("FOLD: ", fold_nb + 1)
    
    train_split, lables_train_split = train_d[train_idx, ::], lables_train[train_idx, ::]
    val_split, lables_val_split = train_d[val_idx, ::], lables_train[val_idx, ::]
    ### Model ###
   
    model = TabNetRegressor(n_d=decision_layer_size, n_a=mask_attention_layer_size, n_steps=1, lambda_sparse=0, optimizer_fn=torch.optim.Adam,
                                    optimizer_params=dict(lr=tabnet_learning_rate, weight_decay=tab_weight_decay), mask_type='entmax', 
                                    scheduler_params=dict(milestones=[50, 100, 150], gamma=0.9), 
                                    scheduler_fn=torch.optim.lr_scheduler.MultiStepLR)
    model.fit(X_train=train_split, y_train=lables_train_split,
              eval_set=[(val_split, lables_val_split)],
              loss_fn = torch.nn.BCEWithLogitsLoss(),
              eval_metric = [LogitsLogLoss])
    
    i = 1
    for x in pred_loader:
        x = x.to(device)
        outputs = model.predict(x.float())
        pred_encode[fold_nb,((i-1)*(outputs.shape[0])):(i*(outputs.shape[0])), ::] = 1 / (1 + np.exp(-outputs))
        i += 1
# Out:
# FOLD:  1
# Device used : cuda
# epoch 0  | loss: 0.39589 | val_0_val_loss: 0.04804 |  0:00:01s
# epoch 1  | loss: 0.02891 | val_0_val_loss: 0.02738 |  0:00:02s
# epoch 2  | loss: 0.02323 | val_0_val_loss: 0.02188 |  0:00:03s
# epoch 3  | loss: 0.0214  | val_0_val_loss: 0.0211  |  0:00:05s
# epoch 4  | loss: 0.02082 | val_0_val_loss: 0.02065 |  0:00:06s
# epoch 5  | loss: 0.02057 | val_0_val_loss: 0.02048 |  0:00:07s
# epoch 6  | loss: 0.02036 | val_0_val_loss: 0.02025 |  0:00:08s
# epoch 7  | loss: 0.02017 | val_0_val_loss: 0.02006 |  0:00:09s
# epoch 8  | loss: 0.01999 | val_0_val_loss: 0.01985 |  0:00:11s
# epoch 9  | loss: 0.01972 | val_0_val_loss: 0.01958 |  0:00:12s
# epoch 10 | loss: 0.01945 | val_0_val_loss: 0.01931 |  0:00:14s
# epoch 11 | loss: 0.01916 | val_0_val_loss: 0.01905 |  0:00:15s
# epoch 12 | loss: 0.01894 | val_0_val_loss: 0.01921 |  0:00:16s
# epoch 13 | loss: 0.01883 | val_0_val_loss: 0.02029 |  0:00:18s
# epoch 14 | loss: 0.01866 | val_0_val_loss: 0.01887 |  0:00:19s
# epoch 15 | loss: 0.01843 | val_0_val_loss: 0.01869 |  0:00:20s
# epoch 16 | loss: 0.01825 | val_0_val_loss: 0.01852 |  0:00:22s
# epoch 17 | loss: 0.01809 | val_0_val_loss: 0.02058 |  0:00:23s
# epoch 18 | loss: 0.01787 | val_0_val_loss: 0.01941 |  0:00:25s
# epoch 19 | loss: 0.01765 | val_0_val_loss: 0.01915 |  0:00:26s
# epoch 20 | loss: 0.01746 | val_0_val_loss: 0.01792 |  0:00:27s
# epoch 21 | loss: 0.01732 | val_0_val_loss: 0.01951 |  0:00:29s
# epoch 22 | loss: 0.0173  | val_0_val_loss: 0.01776 |  0:00:30s
# epoch 23 | loss: 0.01717 | val_0_val_loss: 0.01796 |  0:00:31s
# epoch 24 | loss: 0.01708 | val_0_val_loss: 0.01756 |  0:00:33s
# epoch 25 | loss: 0.01692 | val_0_val_loss: 0.0195  |  0:00:34s
# epoch 26 | loss: 0.01695 | val_0_val_loss: 0.02027 |  0:00:35s
# epoch 27 | loss: 0.01682 | val_0_val_loss: 0.01954 |  0:00:37s
# epoch 28 | loss: 0.01663 | val_0_val_loss: 0.01814 |  0:00:38s
# epoch 29 | loss: 0.01667 | val_0_val_loss: 0.01936 |  0:00:39s
# epoch 30 | loss: 0.01666 | val_0_val_loss: 0.01792 |  0:00:41s
# epoch 31 | loss: 0.01658 | val_0_val_loss: 0.0174  |  0:00:42s
# epoch 32 | loss: 0.01652 | val_0_val_loss: 0.01729 |  0:00:43s
# epoch 33 | loss: 0.01637 | val_0_val_loss: 0.02003 |  0:00:45s
# epoch 34 | loss: 0.01627 | val_0_val_loss: 0.01738 |  0:00:46s
# epoch 35 | loss: 0.01634 | val_0_val_loss: 0.01809 |  0:00:47s
# epoch 36 | loss: 0.01633 | val_0_val_loss: 0.01775 |  0:00:49s
# epoch 37 | loss: 0.01621 | val_0_val_loss: 0.01835 |  0:00:50s
# epoch 38 | loss: 0.01615 | val_0_val_loss: 0.01748 |  0:00:51s
# epoch 39 | loss: 0.01616 | val_0_val_loss: 0.01727 |  0:00:53s
# epoch 40 | loss: 0.01604 | val_0_val_loss: 0.01708 |  0:00:54s
# epoch 41 | loss: 0.01605 | val_0_val_loss: 0.01719 |  0:00:56s
# epoch 42 | loss: 0.01606 | val_0_val_loss: 0.01845 |  0:00:57s
# epoch 43 | loss: 0.0161  | val_0_val_loss: 0.01725 |  0:00:58s
# epoch 44 | loss: 0.01598 | val_0_val_loss: 0.01883 |  0:01:00s
# epoch 45 | loss: 0.01583 | val_0_val_loss: 0.01888 |  0:01:01s
# epoch 46 | loss: 0.0159  | val_0_val_loss: 0.0176  |  0:01:02s
# epoch 47 | loss: 0.01587 | val_0_val_loss: 0.0171  |  0:01:04s
# epoch 48 | loss: 0.0158  | val_0_val_loss: 0.01718 |  0:01:05s
# epoch 49 | loss: 0.01581 | val_0_val_loss: 0.01961 |  0:01:06s
# epoch 50 | loss: 0.01572 | val_0_val_loss: 0.01748 |  0:01:08s
#
# Early stopping occured at epoch 50 with best_epoch = 40 and best_val_0_val_loss = 0.01708
# Best weights from best epoch are automatically used!
# FOLD:  2
# Device used : cuda
# epoch 0  | loss: 0.3988  | val_0_val_loss: 0.05282 |  0:00:01s
# epoch 1  | loss: 0.02889 | val_0_val_loss: 0.02697 |  0:00:02s
# C:\Users\magnu\anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in exp
#   if __name__ == '__main__':
# epoch 2  | loss: 0.0231  | val_0_val_loss: 0.02139 |  0:00:04s
# epoch 3  | loss: 0.02116 | val_0_val_loss: 0.02079 |  0:00:05s
# epoch 4  | loss: 0.02064 | val_0_val_loss: 0.02041 |  0:00:06s
# epoch 5  | loss: 0.02038 | val_0_val_loss: 0.02019 |  0:00:07s
# epoch 6  | loss: 0.02011 | val_0_val_loss: 0.01989 |  0:00:09s
# epoch 7  | loss: 0.01983 | val_0_val_loss: 0.02009 |  0:00:10s
# epoch 8  | loss: 0.01968 | val_0_val_loss: 0.01961 |  0:00:12s
# epoch 9  | loss: 0.01949 | val_0_val_loss: 0.01936 |  0:00:13s
# epoch 10 | loss: 0.01918 | val_0_val_loss: 0.01923 |  0:00:14s
# epoch 11 | loss: 0.01892 | val_0_val_loss: 0.0201  |  0:00:16s
# epoch 12 | loss: 0.01867 | val_0_val_loss: 0.02046 |  0:00:17s
# epoch 13 | loss: 0.01838 | val_0_val_loss: 0.01901 |  0:00:18s
# epoch 14 | loss: 0.01817 | val_0_val_loss: 0.01827 |  0:00:20s
# epoch 15 | loss: 0.01793 | val_0_val_loss: 0.01884 |  0:00:21s
# epoch 16 | loss: 0.01773 | val_0_val_loss: 0.01825 |  0:00:22s
# epoch 17 | loss: 0.01768 | val_0_val_loss: 0.01875 |  0:00:24s
# epoch 18 | loss: 0.01752 | val_0_val_loss: 0.01851 |  0:00:25s
# epoch 19 | loss: 0.01736 | val_0_val_loss: 0.01894 |  0:00:26s
# epoch 20 | loss: 0.01726 | val_0_val_loss: 0.01829 |  0:00:28s
# epoch 21 | loss: 0.01711 | val_0_val_loss: 0.01776 |  0:00:29s
# epoch 22 | loss: 0.01707 | val_0_val_loss: 0.01891 |  0:00:31s
# epoch 23 | loss: 0.01702 | val_0_val_loss: 0.01853 |  0:00:32s
# epoch 24 | loss: 0.01694 | val_0_val_loss: 0.01977 |  0:00:33s
# epoch 25 | loss: 0.01688 | val_0_val_loss: 0.0196  |  0:00:34s
# epoch 26 | loss: 0.01691 | val_0_val_loss: 0.01746 |  0:00:36s
# epoch 27 | loss: 0.01673 | val_0_val_loss: 0.01762 |  0:00:37s
# epoch 28 | loss: 0.01666 | val_0_val_loss: 0.01894 |  0:00:38s
# epoch 29 | loss: 0.01658 | val_0_val_loss: 0.01748 |  0:00:40s
# epoch 30 | loss: 0.01655 | val_0_val_loss: 0.01743 |  0:00:41s
# epoch 31 | loss: 0.01648 | val_0_val_loss: 0.01959 |  0:00:43s
# epoch 32 | loss: 0.01638 | val_0_val_loss: 0.01997 |  0:00:44s
# epoch 33 | loss: 0.01634 | val_0_val_loss: 0.0174  |  0:00:45s
# epoch 34 | loss: 0.01628 | val_0_val_loss: 0.01912 |  0:00:47s
# epoch 35 | loss: 0.01617 | val_0_val_loss: 0.01971 |  0:00:48s
# epoch 36 | loss: 0.01614 | val_0_val_loss: 0.01784 |  0:00:49s
# epoch 37 | loss: 0.01617 | val_0_val_loss: 0.01965 |  0:00:51s
# epoch 38 | loss: 0.01621 | val_0_val_loss: 0.0197  |  0:00:52s
# epoch 39 | loss: 0.01596 | val_0_val_loss: 0.01733 |  0:00:53s
# epoch 40 | loss: 0.01604 | val_0_val_loss: 0.01764 |  0:00:55s
# epoch 41 | loss: 0.0161  | val_0_val_loss: 0.01722 |  0:00:56s
# epoch 42 | loss: 0.01595 | val_0_val_loss: 0.01767 |  0:00:57s
# epoch 43 | loss: 0.01601 | val_0_val_loss: 0.01717 |  0:00:59s
# epoch 44 | loss: 0.0159  | val_0_val_loss: 0.01979 |  0:01:00s
# epoch 45 | loss: 0.01589 | val_0_val_loss: 0.01737 |  0:01:01s
# epoch 46 | loss: 0.01581 | val_0_val_loss: 0.02128 |  0:01:03s
# epoch 47 | loss: 0.01578 | val_0_val_loss: 0.01747 |  0:01:04s
# epoch 48 | loss: 0.01574 | val_0_val_loss: 0.01719 |  0:01:05s
# epoch 49 | loss: 0.01579 | val_0_val_loss: 0.01703 |  0:01:07s
# epoch 50 | loss: 0.01568 | val_0_val_loss: 0.01713 |  0:01:08s
# epoch 51 | loss: 0.01574 | val_0_val_loss: 0.01727 |  0:01:09s
# epoch 52 | loss: 0.01566 | val_0_val_loss: 0.01721 |  0:01:11s
# epoch 53 | loss: 0.01571 | val_0_val_loss: 0.0192  |  0:01:12s
# epoch 54 | loss: 0.01571 | val_0_val_loss: 0.01745 |  0:01:14s
# epoch 55 | loss: 0.01553 | val_0_val_loss: 0.01723 |  0:01:15s
# epoch 56 | loss: 0.01547 | val_0_val_loss: 0.01707 |  0:01:16s
# epoch 57 | loss: 0.01548 | val_0_val_loss: 0.01717 |  0:01:18s
# epoch 58 | loss: 0.01543 | val_0_val_loss: 0.01714 |  0:01:19s
# epoch 59 | loss: 0.0155  | val_0_val_loss: 0.01756 |  0:01:20s
#
# Early stopping occured at epoch 59 with best_epoch = 49 and best_val_0_val_loss = 0.01703
# Best weights from best epoch are automatically used!
# FOLD:  3
# Device used : cuda
# epoch 0  | loss: 0.40047 | val_0_val_loss: 0.06598 |  0:00:01s
# C:\Users\magnu\anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in exp
#   if __name__ == '__main__':
# epoch 1  | loss: 0.03008 | val_0_val_loss: 0.02986 |  0:00:02s
# epoch 2  | loss: 0.02406 | val_0_val_loss: 0.02214 |  0:00:04s
# epoch 3  | loss: 0.02142 | val_0_val_loss: 0.02117 |  0:00:05s
# epoch 4  | loss: 0.0207  | val_0_val_loss: 0.02073 |  0:00:06s
# epoch 5  | loss: 0.0204  | val_0_val_loss: 0.02045 |  0:00:08s
# epoch 6  | loss: 0.02014 | val_0_val_loss: 0.02026 |  0:00:09s
# epoch 7  | loss: 0.01992 | val_0_val_loss: 0.02002 |  0:00:11s
# epoch 8  | loss: 0.01961 | val_0_val_loss: 0.02073 |  0:00:12s
# epoch 9  | loss: 0.01934 | val_0_val_loss: 0.01946 |  0:00:13s
# epoch 10 | loss: 0.019   | val_0_val_loss: 0.01923 |  0:00:15s
# epoch 11 | loss: 0.01871 | val_0_val_loss: 0.01899 |  0:00:16s
# epoch 12 | loss: 0.01851 | val_0_val_loss: 0.01906 |  0:00:17s
# epoch 13 | loss: 0.0183  | val_0_val_loss: 0.01873 |  0:00:19s
# epoch 14 | loss: 0.01817 | val_0_val_loss: 0.02021 |  0:00:20s
# epoch 15 | loss: 0.01792 | val_0_val_loss: 0.01847 |  0:00:22s
# epoch 16 | loss: 0.01785 | val_0_val_loss: 0.01924 |  0:00:23s
# epoch 17 | loss: 0.01762 | val_0_val_loss: 0.01853 |  0:00:24s
# epoch 18 | loss: 0.01757 | val_0_val_loss: 0.01996 |  0:00:26s
# epoch 19 | loss: 0.01743 | val_0_val_loss: 0.0197  |  0:00:27s
# epoch 20 | loss: 0.01737 | val_0_val_loss: 0.01979 |  0:00:29s
# epoch 21 | loss: 0.01724 | val_0_val_loss: 0.01797 |  0:00:30s
# epoch 22 | loss: 0.01707 | val_0_val_loss: 0.0191  |  0:00:31s
# epoch 23 | loss: 0.01699 | val_0_val_loss: 0.01784 |  0:00:33s
# epoch 24 | loss: 0.01706 | val_0_val_loss: 0.01818 |  0:00:34s
# epoch 25 | loss: 0.01691 | val_0_val_loss: 0.01771 |  0:00:36s
# epoch 26 | loss: 0.01681 | val_0_val_loss: 0.01953 |  0:00:37s
# epoch 27 | loss: 0.01667 | val_0_val_loss: 0.0184  |  0:00:39s
# epoch 28 | loss: 0.01663 | val_0_val_loss: 0.01948 |  0:00:41s
# epoch 29 | loss: 0.01655 | val_0_val_loss: 0.01981 |  0:00:42s
# epoch 30 | loss: 0.01641 | val_0_val_loss: 0.01946 |  0:00:44s
# epoch 31 | loss: 0.01646 | val_0_val_loss: 0.01982 |  0:00:46s
# epoch 32 | loss: 0.01644 | val_0_val_loss: 0.01747 |  0:00:47s
# epoch 33 | loss: 0.01633 | val_0_val_loss: 0.01916 |  0:00:49s
# epoch 34 | loss: 0.01633 | val_0_val_loss: 0.01758 |  0:00:50s
# epoch 35 | loss: 0.01617 | val_0_val_loss: 0.01844 |  0:00:52s
# epoch 36 | loss: 0.0161  | val_0_val_loss: 0.01921 |  0:00:53s
# epoch 37 | loss: 0.01615 | val_0_val_loss: 0.01756 |  0:00:54s
# epoch 38 | loss: 0.016   | val_0_val_loss: 0.01787 |  0:00:56s
# epoch 39 | loss: 0.01602 | val_0_val_loss: 0.01747 |  0:00:57s
# epoch 40 | loss: 0.01603 | val_0_val_loss: 0.01891 |  0:00:59s
# epoch 41 | loss: 0.01613 | val_0_val_loss: 0.0197  |  0:01:00s
# epoch 42 | loss: 0.01594 | val_0_val_loss: 0.01716 |  0:01:02s
# epoch 43 | loss: 0.01581 | val_0_val_loss: 0.01804 |  0:01:03s
# epoch 44 | loss: 0.01579 | val_0_val_loss: 0.01769 |  0:01:04s
# epoch 45 | loss: 0.01596 | val_0_val_loss: 0.01774 |  0:01:06s
# epoch 46 | loss: 0.016   | val_0_val_loss: 0.01876 |  0:01:07s
# epoch 47 | loss: 0.01585 | val_0_val_loss: 0.01727 |  0:01:08s
# epoch 48 | loss: 0.01576 | val_0_val_loss: 0.01901 |  0:01:10s
# epoch 49 | loss: 0.01591 | val_0_val_loss: 0.01748 |  0:01:11s
# epoch 50 | loss: 0.01578 | val_0_val_loss: 0.01724 |  0:01:13s
# epoch 51 | loss: 0.01565 | val_0_val_loss: 0.01751 |  0:01:14s
# epoch 52 | loss: 0.01556 | val_0_val_loss: 0.01713 |  0:01:16s
# epoch 53 | loss: 0.0155  | val_0_val_loss: 0.01847 |  0:01:17s
# epoch 54 | loss: 0.01557 | val_0_val_loss: 0.01734 |  0:01:18s
# epoch 55 | loss: 0.01565 | val_0_val_loss: 0.01856 |  0:01:20s
# epoch 56 | loss: 0.01556 | val_0_val_loss: 0.01724 |  0:01:21s
# epoch 57 | loss: 0.0155  | val_0_val_loss: 0.01717 |  0:01:23s
# epoch 58 | loss: 0.01541 | val_0_val_loss: 0.01722 |  0:01:24s
# epoch 59 | loss: 0.0155  | val_0_val_loss: 0.0174  |  0:01:25s
# epoch 60 | loss: 0.01548 | val_0_val_loss: 0.01765 |  0:01:26s
# epoch 61 | loss: 0.01551 | val_0_val_loss: 0.01722 |  0:01:28s
# epoch 62 | loss: 0.01549 | val_0_val_loss: 0.01762 |  0:01:29s
#
# Early stopping occured at epoch 62 with best_epoch = 52 and best_val_0_val_loss = 0.01713
# Best weights from best epoch are automatically used!
# FOLD:  4
# Device used : cuda
# epoch 0  | loss: 0.39988 | val_0_val_loss: 0.0605  |  0:00:01s
# epoch 1  | loss: 0.03005 | val_0_val_loss: 0.0281  |  0:00:02s
# C:\Users\magnu\anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in exp
#   if __name__ == '__main__':
# epoch 2  | loss: 0.02417 | val_0_val_loss: 0.02178 |  0:00:04s
# epoch 3  | loss: 0.0215  | val_0_val_loss: 0.02082 |  0:00:05s
# epoch 4  | loss: 0.02082 | val_0_val_loss: 0.02059 |  0:00:06s
# epoch 5  | loss: 0.02065 | val_0_val_loss: 0.02048 |  0:00:08s
# epoch 6  | loss: 0.02049 | val_0_val_loss: 0.02035 |  0:00:09s
# epoch 7  | loss: 0.02029 | val_0_val_loss: 0.02014 |  0:00:11s
# epoch 8  | loss: 0.02003 | val_0_val_loss: 0.02    |  0:00:12s
# epoch 9  | loss: 0.01985 | val_0_val_loss: 0.01985 |  0:00:13s
# epoch 10 | loss: 0.01958 | val_0_val_loss: 0.0195  |  0:00:15s
# epoch 11 | loss: 0.01925 | val_0_val_loss: 0.01928 |  0:00:16s
# epoch 12 | loss: 0.01882 | val_0_val_loss: 0.0194  |  0:00:17s
# epoch 13 | loss: 0.01853 | val_0_val_loss: 0.01876 |  0:00:19s
# epoch 14 | loss: 0.01828 | val_0_val_loss: 0.01821 |  0:00:20s
# epoch 15 | loss: 0.01803 | val_0_val_loss: 0.01821 |  0:00:21s
# epoch 16 | loss: 0.01789 | val_0_val_loss: 0.01812 |  0:00:23s
# epoch 17 | loss: 0.01769 | val_0_val_loss: 0.01831 |  0:00:24s
# epoch 18 | loss: 0.01754 | val_0_val_loss: 0.018   |  0:00:26s
# epoch 19 | loss: 0.01746 | val_0_val_loss: 0.01777 |  0:00:27s
# epoch 20 | loss: 0.01735 | val_0_val_loss: 0.01772 |  0:00:29s
# epoch 21 | loss: 0.01719 | val_0_val_loss: 0.0179  |  0:00:30s
# epoch 22 | loss: 0.01709 | val_0_val_loss: 0.01762 |  0:00:31s
# epoch 23 | loss: 0.017   | val_0_val_loss: 0.01786 |  0:00:33s
# epoch 24 | loss: 0.01682 | val_0_val_loss: 0.01764 |  0:00:34s
# epoch 25 | loss: 0.01685 | val_0_val_loss: 0.01856 |  0:00:36s
# epoch 26 | loss: 0.01669 | val_0_val_loss: 0.0177  |  0:00:37s
# epoch 27 | loss: 0.01662 | val_0_val_loss: 0.01743 |  0:00:38s
# epoch 28 | loss: 0.01657 | val_0_val_loss: 0.01794 |  0:00:40s
# epoch 29 | loss: 0.01653 | val_0_val_loss: 0.01756 |  0:00:41s
# epoch 30 | loss: 0.01649 | val_0_val_loss: 0.01787 |  0:00:42s
# epoch 31 | loss: 0.01645 | val_0_val_loss: 0.0173  |  0:00:44s
# epoch 32 | loss: 0.01639 | val_0_val_loss: 0.01858 |  0:00:45s
# epoch 33 | loss: 0.01628 | val_0_val_loss: 0.01751 |  0:00:47s
# epoch 34 | loss: 0.01626 | val_0_val_loss: 0.01758 |  0:00:48s
# epoch 35 | loss: 0.01624 | val_0_val_loss: 0.01757 |  0:00:49s
# epoch 36 | loss: 0.01627 | val_0_val_loss: 0.01777 |  0:00:51s
# epoch 37 | loss: 0.0163  | val_0_val_loss: 0.01746 |  0:00:52s
# epoch 38 | loss: 0.01611 | val_0_val_loss: 0.01741 |  0:00:54s
# epoch 39 | loss: 0.01601 | val_0_val_loss: 0.01766 |  0:00:55s
# epoch 40 | loss: 0.01608 | val_0_val_loss: 0.01815 |  0:00:56s
# epoch 41 | loss: 0.01607 | val_0_val_loss: 0.01734 |  0:00:58s
#
# Early stopping occured at epoch 41 with best_epoch = 31 and best_val_0_val_loss = 0.0173
# Best weights from best epoch are automatically used!
# FOLD:  5
# Device used : cuda
# epoch 0  | loss: 0.39457 | val_0_val_loss: 0.06052 |  0:00:01s
# epoch 1  | loss: 0.02998 | val_0_val_loss: 0.02822 |  0:00:02s
# epoch 2  | loss: 0.02413 | val_0_val_loss: 0.02174 |  0:00:04s
# epoch 3  | loss: 0.0216  | val_0_val_loss: 0.02078 |  0:00:05s
# epoch 4  | loss: 0.0209  | val_0_val_loss: 0.02051 |  0:00:06s
# epoch 5  | loss: 0.02062 | val_0_val_loss: 0.02048 |  0:00:08s
# epoch 6  | loss: 0.02047 | val_0_val_loss: 0.02032 |  0:00:09s
# epoch 7  | loss: 0.02024 | val_0_val_loss: 0.02013 |  0:00:10s
# epoch 8  | loss: 0.02007 | val_0_val_loss: 0.01999 |  0:00:12s
# epoch 9  | loss: 0.01983 | val_0_val_loss: 0.01975 |  0:00:13s
# epoch 10 | loss: 0.01958 | val_0_val_loss: 0.0197  |  0:00:14s
# epoch 11 | loss: 0.0193  | val_0_val_loss: 0.01942 |  0:00:16s
# epoch 12 | loss: 0.019   | val_0_val_loss: 0.01923 |  0:00:17s
# epoch 13 | loss: 0.01865 | val_0_val_loss: 0.01879 |  0:00:18s
# epoch 14 | loss: 0.01829 | val_0_val_loss: 0.01833 |  0:00:20s
# epoch 15 | loss: 0.01802 | val_0_val_loss: 0.01834 |  0:00:21s
# epoch 16 | loss: 0.01777 | val_0_val_loss: 0.01824 |  0:00:23s
# epoch 17 | loss: 0.0176  | val_0_val_loss: 0.01828 |  0:00:24s
# epoch 18 | loss: 0.01749 | val_0_val_loss: 0.01822 |  0:00:25s
# epoch 19 | loss: 0.0174  | val_0_val_loss: 0.01776 |  0:00:27s
# epoch 20 | loss: 0.01734 | val_0_val_loss: 0.01812 |  0:00:28s
# epoch 21 | loss: 0.0172  | val_0_val_loss: 0.01779 |  0:00:30s
# epoch 22 | loss: 0.01711 | val_0_val_loss: 0.01761 |  0:00:31s
# epoch 23 | loss: 0.01704 | val_0_val_loss: 0.01755 |  0:00:33s
# epoch 24 | loss: 0.01701 | val_0_val_loss: 0.01832 |  0:00:34s
# epoch 25 | loss: 0.01689 | val_0_val_loss: 0.01761 |  0:00:35s
# epoch 26 | loss: 0.01687 | val_0_val_loss: 0.01747 |  0:00:37s
# epoch 27 | loss: 0.0168  | val_0_val_loss: 0.01733 |  0:00:38s
# epoch 28 | loss: 0.01667 | val_0_val_loss: 0.01733 |  0:00:39s
# epoch 29 | loss: 0.01664 | val_0_val_loss: 0.01928 |  0:00:41s
# epoch 30 | loss: 0.01651 | val_0_val_loss: 0.01765 |  0:00:42s
# epoch 31 | loss: 0.01645 | val_0_val_loss: 0.01828 |  0:00:44s
# epoch 32 | loss: 0.01645 | val_0_val_loss: 0.019   |  0:00:45s
# epoch 33 | loss: 0.01643 | val_0_val_loss: 0.0176  |  0:00:46s
# epoch 34 | loss: 0.01626 | val_0_val_loss: 0.01736 |  0:00:48s
# epoch 35 | loss: 0.01636 | val_0_val_loss: 0.01756 |  0:00:49s
# epoch 36 | loss: 0.01633 | val_0_val_loss: 0.01913 |  0:00:51s
# epoch 37 | loss: 0.01622 | val_0_val_loss: 0.01813 |  0:00:52s
#
# Early stopping occured at epoch 37 with best_epoch = 27 and best_val_0_val_loss = 0.01733
# Best weights from best epoch are automatically used!
# FOLD:  6
# Device used : cuda
# epoch 0  | loss: 0.40353 | val_0_val_loss: 0.06494 |  0:00:01s
# C:\Users\magnu\anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in exp
#   if __name__ == '__main__':
# epoch 1  | loss: 0.03099 | val_0_val_loss: 0.03059 |  0:00:02s
# epoch 2  | loss: 0.02546 | val_0_val_loss: 0.0227  |  0:00:04s
# epoch 3  | loss: 0.02181 | val_0_val_loss: 0.02127 |  0:00:05s
# epoch 4  | loss: 0.02096 | val_0_val_loss: 0.02075 |  0:00:07s
# epoch 5  | loss: 0.02055 | val_0_val_loss: 0.02051 |  0:00:08s
# epoch 6  | loss: 0.02032 | val_0_val_loss: 0.02033 |  0:00:10s
# epoch 7  | loss: 0.02006 | val_0_val_loss: 0.02009 |  0:00:11s
# epoch 8  | loss: 0.01982 | val_0_val_loss: 0.01992 |  0:00:12s
# epoch 9  | loss: 0.01952 | val_0_val_loss: 0.01966 |  0:00:14s
# epoch 10 | loss: 0.01919 | val_0_val_loss: 0.01938 |  0:00:15s
# epoch 11 | loss: 0.01892 | val_0_val_loss: 0.01931 |  0:00:16s
# epoch 12 | loss: 0.01862 | val_0_val_loss: 0.01908 |  0:00:17s
# epoch 13 | loss: 0.0184  | val_0_val_loss: 0.01879 |  0:00:19s
# epoch 14 | loss: 0.01815 | val_0_val_loss: 0.01896 |  0:00:20s
# epoch 15 | loss: 0.01798 | val_0_val_loss: 0.01866 |  0:00:22s
# epoch 16 | loss: 0.01776 | val_0_val_loss: 0.01877 |  0:00:23s
# epoch 17 | loss: 0.01763 | val_0_val_loss: 0.0197  |  0:00:24s
# epoch 18 | loss: 0.01755 | val_0_val_loss: 0.01891 |  0:00:26s
# epoch 19 | loss: 0.01746 | val_0_val_loss: 0.0192  |  0:00:27s
# epoch 20 | loss: 0.01728 | val_0_val_loss: 0.01841 |  0:00:28s
# epoch 21 | loss: 0.01721 | val_0_val_loss: 0.01872 |  0:00:30s
# epoch 22 | loss: 0.01708 | val_0_val_loss: 0.01819 |  0:00:31s
# epoch 23 | loss: 0.01704 | val_0_val_loss: 0.01816 |  0:00:33s
# epoch 24 | loss: 0.01696 | val_0_val_loss: 0.01806 |  0:00:34s
# epoch 25 | loss: 0.01687 | val_0_val_loss: 0.0194  |  0:00:35s
# epoch 26 | loss: 0.01691 | val_0_val_loss: 0.0179  |  0:00:37s
# epoch 27 | loss: 0.01679 | val_0_val_loss: 0.01993 |  0:00:38s
# epoch 28 | loss: 0.01659 | val_0_val_loss: 0.0181  |  0:00:40s
# epoch 29 | loss: 0.01656 | val_0_val_loss: 0.01814 |  0:00:41s
# epoch 30 | loss: 0.01657 | val_0_val_loss: 0.01996 |  0:00:42s
# epoch 31 | loss: 0.01641 | val_0_val_loss: 0.01854 |  0:00:44s
# epoch 32 | loss: 0.01634 | val_0_val_loss: 0.01786 |  0:00:45s
# epoch 33 | loss: 0.01638 | val_0_val_loss: 0.01805 |  0:00:46s
# epoch 34 | loss: 0.01624 | val_0_val_loss: 0.0175  |  0:00:48s
# epoch 35 | loss: 0.01624 | val_0_val_loss: 0.01865 |  0:00:49s
# epoch 36 | loss: 0.01619 | val_0_val_loss: 0.01742 |  0:00:51s
# epoch 37 | loss: 0.01608 | val_0_val_loss: 0.01745 |  0:00:52s
# epoch 38 | loss: 0.01608 | val_0_val_loss: 0.02008 |  0:00:54s
# epoch 39 | loss: 0.01598 | val_0_val_loss: 0.01766 |  0:00:55s
# epoch 40 | loss: 0.01594 | val_0_val_loss: 0.01955 |  0:00:57s
# epoch 41 | loss: 0.01601 | val_0_val_loss: 0.0186  |  0:00:58s
# epoch 42 | loss: 0.01594 | val_0_val_loss: 0.01871 |  0:00:59s
# epoch 43 | loss: 0.01592 | val_0_val_loss: 0.01773 |  0:01:01s
# epoch 44 | loss: 0.01594 | val_0_val_loss: 0.0179  |  0:01:02s
# epoch 45 | loss: 0.01583 | val_0_val_loss: 0.01724 |  0:01:03s
# epoch 46 | loss: 0.01578 | val_0_val_loss: 0.0176  |  0:01:05s
# epoch 47 | loss: 0.01593 | val_0_val_loss: 0.01751 |  0:01:06s
# epoch 48 | loss: 0.01579 | val_0_val_loss: 0.01743 |  0:01:08s
# epoch 49 | loss: 0.01572 | val_0_val_loss: 0.01748 |  0:01:09s
# epoch 50 | loss: 0.01565 | val_0_val_loss: 0.01969 |  0:01:10s
# epoch 51 | loss: 0.01567 | val_0_val_loss: 0.01731 |  0:01:12s
# epoch 52 | loss: 0.01565 | val_0_val_loss: 0.01783 |  0:01:13s
# epoch 53 | loss: 0.01552 | val_0_val_loss: 0.0174  |  0:01:14s
# epoch 54 | loss: 0.01553 | val_0_val_loss: 0.0176  |  0:01:16s
# epoch 55 | loss: 0.01562 | val_0_val_loss: 0.01758 |  0:01:17s
#
# Early stopping occured at epoch 55 with best_epoch = 45 and best_val_0_val_loss = 0.01724
# Best weights from best epoch are automatically used!
# FOLD:  7
# Device used : cuda
# epoch 0  | loss: 0.39932 | val_0_val_loss: 0.05674 |  0:00:01s
# epoch 1  | loss: 0.03047 | val_0_val_loss: 0.02939 |  0:00:02s
# epoch 2  | loss: 0.02484 | val_0_val_loss: 0.02222 |  0:00:03s
# epoch 3  | loss: 0.02182 | val_0_val_loss: 0.02107 |  0:00:05s
# epoch 4  | loss: 0.02113 | val_0_val_loss: 0.02088 |  0:00:06s
# epoch 5  | loss: 0.02081 | val_0_val_loss: 0.02046 |  0:00:08s
# epoch 6  | loss: 0.02044 | val_0_val_loss: 0.02012 |  0:00:09s
# epoch 7  | loss: 0.02006 | val_0_val_loss: 0.0199  |  0:00:10s
# epoch 8  | loss: 0.01977 | val_0_val_loss: 0.01958 |  0:00:12s
# epoch 9  | loss: 0.01949 | val_0_val_loss: 0.0196  |  0:00:13s
# epoch 10 | loss: 0.01926 | val_0_val_loss: 0.01951 |  0:00:14s
# epoch 11 | loss: 0.01902 | val_0_val_loss: 0.01911 |  0:00:16s
# epoch 12 | loss: 0.01883 | val_0_val_loss: 0.01876 |  0:00:17s
# epoch 13 | loss: 0.01851 | val_0_val_loss: 0.01861 |  0:00:19s
# epoch 14 | loss: 0.01832 | val_0_val_loss: 0.01884 |  0:00:20s
# epoch 15 | loss: 0.0181  | val_0_val_loss: 0.01865 |  0:00:22s
# epoch 16 | loss: 0.01785 | val_0_val_loss: 0.01813 |  0:00:23s
# epoch 17 | loss: 0.0177  | val_0_val_loss: 0.0196  |  0:00:24s
# epoch 18 | loss: 0.01756 | val_0_val_loss: 0.01799 |  0:00:26s
# epoch 19 | loss: 0.01737 | val_0_val_loss: 0.01797 |  0:00:27s
# epoch 20 | loss: 0.0174  | val_0_val_loss: 0.01845 |  0:00:29s
# epoch 21 | loss: 0.01729 | val_0_val_loss: 0.01863 |  0:00:30s
# epoch 22 | loss: 0.01726 | val_0_val_loss: 0.01813 |  0:00:31s
# epoch 23 | loss: 0.01709 | val_0_val_loss: 0.01759 |  0:00:33s
# epoch 24 | loss: 0.01703 | val_0_val_loss: 0.01832 |  0:00:34s
# epoch 25 | loss: 0.01692 | val_0_val_loss: 0.01993 |  0:00:36s
# epoch 26 | loss: 0.01687 | val_0_val_loss: 0.01814 |  0:00:37s
# epoch 27 | loss: 0.01677 | val_0_val_loss: 0.0175  |  0:00:38s
# epoch 28 | loss: 0.01674 | val_0_val_loss: 0.01766 |  0:00:40s
# epoch 29 | loss: 0.01662 | val_0_val_loss: 0.01809 |  0:00:41s
# epoch 30 | loss: 0.01653 | val_0_val_loss: 0.01731 |  0:00:42s
# epoch 31 | loss: 0.01644 | val_0_val_loss: 0.01923 |  0:00:44s
# epoch 32 | loss: 0.01632 | val_0_val_loss: 0.01709 |  0:00:45s
# epoch 33 | loss: 0.01624 | val_0_val_loss: 0.01727 |  0:00:47s
# epoch 34 | loss: 0.01631 | val_0_val_loss: 0.01718 |  0:00:48s
# epoch 35 | loss: 0.01624 | val_0_val_loss: 0.01992 |  0:00:49s
# epoch 36 | loss: 0.01616 | val_0_val_loss: 0.01831 |  0:00:51s
# epoch 37 | loss: 0.01602 | val_0_val_loss: 0.01755 |  0:00:52s
# epoch 38 | loss: 0.01609 | val_0_val_loss: 0.01822 |  0:00:54s
# epoch 39 | loss: 0.01608 | val_0_val_loss: 0.01711 |  0:00:55s
# epoch 40 | loss: 0.01596 | val_0_val_loss: 0.01692 |  0:00:56s
# epoch 41 | loss: 0.01589 | val_0_val_loss: 0.01909 |  0:00:58s
# epoch 42 | loss: 0.01588 | val_0_val_loss: 0.01808 |  0:00:59s
# epoch 43 | loss: 0.01591 | val_0_val_loss: 0.01717 |  0:01:01s
# epoch 44 | loss: 0.01594 | val_0_val_loss: 0.01755 |  0:01:02s
# epoch 45 | loss: 0.01592 | val_0_val_loss: 0.01703 |  0:01:04s
# epoch 46 | loss: 0.0159  | val_0_val_loss: 0.01779 |  0:01:05s
# epoch 47 | loss: 0.01572 | val_0_val_loss: 0.01718 |  0:01:06s
# epoch 48 | loss: 0.01573 | val_0_val_loss: 0.01752 |  0:01:08s
# epoch 49 | loss: 0.01577 | val_0_val_loss: 0.01697 |  0:01:09s
# epoch 50 | loss: 0.01567 | val_0_val_loss: 0.01712 |  0:01:10s
#
# Early stopping occured at epoch 50 with best_epoch = 40 and best_val_0_val_loss = 0.01692
# Best weights from best epoch are automatically used!
# FOLD:  8
# Device used : cuda
# epoch 0  | loss: 0.39492 | val_0_val_loss: 0.05752 |  0:00:01s
# epoch 1  | loss: 0.02947 | val_0_val_loss: 0.02764 |  0:00:02s
# epoch 2  | loss: 0.02358 | val_0_val_loss: 0.02133 |  0:00:04s
# epoch 3  | loss: 0.02148 | val_0_val_loss: 0.02066 |  0:00:05s
# epoch 4  | loss: 0.02093 | val_0_val_loss: 0.02039 |  0:00:07s
# epoch 5  | loss: 0.02064 | val_0_val_loss: 0.02012 |  0:00:08s
# epoch 6  | loss: 0.02037 | val_0_val_loss: 0.01996 |  0:00:09s
# epoch 7  | loss: 0.02008 | val_0_val_loss: 0.01967 |  0:00:11s
# epoch 8  | loss: 0.01972 | val_0_val_loss: 0.01935 |  0:00:12s
# epoch 9  | loss: 0.01933 | val_0_val_loss: 0.01917 |  0:00:13s
# epoch 10 | loss: 0.01907 | val_0_val_loss: 0.01952 |  0:00:15s
# epoch 11 | loss: 0.01878 | val_0_val_loss: 0.01892 |  0:00:16s
# epoch 12 | loss: 0.01854 | val_0_val_loss: 0.0189  |  0:00:18s
# epoch 13 | loss: 0.01826 | val_0_val_loss: 0.01859 |  0:00:19s
# epoch 14 | loss: 0.018   | val_0_val_loss: 0.01862 |  0:00:20s
# epoch 15 | loss: 0.0179  | val_0_val_loss: 0.01909 |  0:00:22s
# epoch 16 | loss: 0.01778 | val_0_val_loss: 0.01833 |  0:00:23s
# epoch 17 | loss: 0.01765 | val_0_val_loss: 0.01867 |  0:00:24s
# epoch 18 | loss: 0.01756 | val_0_val_loss: 0.01827 |  0:00:26s
# epoch 19 | loss: 0.01739 | val_0_val_loss: 0.01908 |  0:00:27s
# epoch 20 | loss: 0.01723 | val_0_val_loss: 0.01791 |  0:00:28s
# epoch 21 | loss: 0.0173  | val_0_val_loss: 0.0182  |  0:00:30s
# epoch 22 | loss: 0.01728 | val_0_val_loss: 0.01777 |  0:00:31s
# epoch 23 | loss: 0.01713 | val_0_val_loss: 0.01916 |  0:00:32s
# epoch 24 | loss: 0.01715 | val_0_val_loss: 0.01763 |  0:00:34s
# epoch 25 | loss: 0.01693 | val_0_val_loss: 0.01903 |  0:00:36s
# epoch 26 | loss: 0.0169  | val_0_val_loss: 0.01778 |  0:00:37s
# epoch 27 | loss: 0.01688 | val_0_val_loss: 0.01915 |  0:00:39s
# epoch 28 | loss: 0.01676 | val_0_val_loss: 0.01754 |  0:00:40s
# epoch 29 | loss: 0.01678 | val_0_val_loss: 0.01758 |  0:00:42s
# epoch 30 | loss: 0.01669 | val_0_val_loss: 0.01976 |  0:00:43s
# epoch 31 | loss: 0.01654 | val_0_val_loss: 0.01761 |  0:00:45s
# epoch 32 | loss: 0.01653 | val_0_val_loss: 0.01755 |  0:00:46s
# epoch 33 | loss: 0.01661 | val_0_val_loss: 0.01743 |  0:00:48s
# epoch 34 | loss: 0.01646 | val_0_val_loss: 0.01734 |  0:00:49s
# epoch 35 | loss: 0.01639 | val_0_val_loss: 0.01751 |  0:00:50s
# epoch 36 | loss: 0.01632 | val_0_val_loss: 0.01755 |  0:00:52s
# epoch 37 | loss: 0.01629 | val_0_val_loss: 0.01875 |  0:00:53s
# epoch 38 | loss: 0.0162  | val_0_val_loss: 0.01726 |  0:00:54s
# epoch 39 | loss: 0.01614 | val_0_val_loss: 0.01986 |  0:00:56s
# epoch 40 | loss: 0.01609 | val_0_val_loss: 0.01908 |  0:00:57s
# epoch 41 | loss: 0.01611 | val_0_val_loss: 0.01965 |  0:00:58s
# epoch 42 | loss: 0.01614 | val_0_val_loss: 0.01715 |  0:01:00s
# epoch 43 | loss: 0.01603 | val_0_val_loss: 0.01853 |  0:01:01s
# epoch 44 | loss: 0.01594 | val_0_val_loss: 0.01708 |  0:01:02s
# epoch 45 | loss: 0.01593 | val_0_val_loss: 0.01752 |  0:01:04s
# epoch 46 | loss: 0.01583 | val_0_val_loss: 0.01876 |  0:01:05s
# epoch 47 | loss: 0.01588 | val_0_val_loss: 0.01707 |  0:01:06s
# epoch 48 | loss: 0.01602 | val_0_val_loss: 0.01869 |  0:01:08s
# epoch 49 | loss: 0.01591 | val_0_val_loss: 0.01718 |  0:01:09s
# epoch 50 | loss: 0.01578 | val_0_val_loss: 0.0173  |  0:01:10s
# epoch 51 | loss: 0.01575 | val_0_val_loss: 0.0172  |  0:01:12s
# epoch 52 | loss: 0.01561 | val_0_val_loss: 0.01753 |  0:01:13s
# epoch 53 | loss: 0.01572 | val_0_val_loss: 0.01791 |  0:01:14s
# epoch 54 | loss: 0.01603 | val_0_val_loss: 0.0174  |  0:01:16s
# epoch 55 | loss: 0.0159  | val_0_val_loss: 0.01707 |  0:01:17s
# epoch 56 | loss: 0.01565 | val_0_val_loss: 0.01689 |  0:01:18s
# epoch 57 | loss: 0.01561 | val_0_val_loss: 0.01722 |  0:01:20s
# epoch 58 | loss: 0.0156  | val_0_val_loss: 0.01697 |  0:01:21s
# epoch 59 | loss: 0.01571 | val_0_val_loss: 0.01795 |  0:01:23s
# epoch 60 | loss: 0.01572 | val_0_val_loss: 0.01717 |  0:01:24s
# epoch 61 | loss: 0.01563 | val_0_val_loss: 0.0179  |  0:01:25s
# epoch 62 | loss: 0.0156  | val_0_val_loss: 0.02813 |  0:01:27s
# epoch 63 | loss: 0.01561 | val_0_val_loss: 0.01724 |  0:01:28s
# epoch 64 | loss: 0.01564 | val_0_val_loss: 0.01747 |  0:01:29s
# epoch 65 | loss: 0.01562 | val_0_val_loss: 0.01709 |  0:01:31s
# epoch 66 | loss: 0.01542 | val_0_val_loss: 0.01711 |  0:01:32s
#
# Early stopping occured at epoch 66 with best_epoch = 56 and best_val_0_val_loss = 0.01689
# Best weights from best epoch are automatically used!
# FOLD:  9
# Device used : cuda
# epoch 0  | loss: 0.40331 | val_0_val_loss: 0.06792 |  0:00:01s
# C:\Users\magnu\anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in exp
#   if __name__ == '__main__':
# epoch 1  | loss: 0.03014 | val_0_val_loss: 0.02916 |  0:00:02s
# epoch 2  | loss: 0.02428 | val_0_val_loss: 0.02219 |  0:00:04s
# epoch 3  | loss: 0.02149 | val_0_val_loss: 0.02088 |  0:00:05s
# epoch 4  | loss: 0.02083 | val_0_val_loss: 0.02053 |  0:00:07s
# epoch 5  | loss: 0.02046 | val_0_val_loss: 0.02027 |  0:00:08s
# epoch 6  | loss: 0.02033 | val_0_val_loss: 0.02014 |  0:00:10s
# epoch 7  | loss: 0.0201  | val_0_val_loss: 0.01996 |  0:00:11s
# epoch 8  | loss: 0.01999 | val_0_val_loss: 0.0199  |  0:00:13s
# epoch 9  | loss: 0.01982 | val_0_val_loss: 0.01977 |  0:00:14s
# epoch 10 | loss: 0.01955 | val_0_val_loss: 0.01955 |  0:00:16s
# epoch 11 | loss: 0.0193  | val_0_val_loss: 0.0194  |  0:00:17s
# epoch 12 | loss: 0.01906 | val_0_val_loss: 0.01899 |  0:00:18s
# epoch 13 | loss: 0.01872 | val_0_val_loss: 0.01968 |  0:00:20s
# epoch 14 | loss: 0.0184  | val_0_val_loss: 0.01863 |  0:00:21s
# epoch 15 | loss: 0.0182  | val_0_val_loss: 0.01866 |  0:00:22s
# epoch 16 | loss: 0.01801 | val_0_val_loss: 0.01916 |  0:00:24s
# epoch 17 | loss: 0.01777 | val_0_val_loss: 0.01855 |  0:00:25s
# epoch 18 | loss: 0.01768 | val_0_val_loss: 0.01797 |  0:00:27s
# epoch 19 | loss: 0.01753 | val_0_val_loss: 0.0182  |  0:00:28s
# epoch 20 | loss: 0.01743 | val_0_val_loss: 0.01914 |  0:00:29s
# epoch 21 | loss: 0.01736 | val_0_val_loss: 0.01766 |  0:00:31s
# epoch 22 | loss: 0.01719 | val_0_val_loss: 0.01765 |  0:00:32s
# epoch 23 | loss: 0.01706 | val_0_val_loss: 0.01763 |  0:00:34s
# epoch 24 | loss: 0.01706 | val_0_val_loss: 0.01771 |  0:00:35s
# epoch 25 | loss: 0.01696 | val_0_val_loss: 0.01781 |  0:00:36s
# epoch 26 | loss: 0.0169  | val_0_val_loss: 0.01757 |  0:00:38s
# epoch 27 | loss: 0.01694 | val_0_val_loss: 0.0196  |  0:00:39s
# epoch 28 | loss: 0.01683 | val_0_val_loss: 0.01796 |  0:00:41s
# epoch 29 | loss: 0.01665 | val_0_val_loss: 0.01754 |  0:00:42s
# epoch 30 | loss: 0.0166  | val_0_val_loss: 0.01929 |  0:00:43s
# epoch 31 | loss: 0.01654 | val_0_val_loss: 0.01759 |  0:00:45s
# epoch 32 | loss: 0.01651 | val_0_val_loss: 0.01739 |  0:00:46s
# epoch 33 | loss: 0.01648 | val_0_val_loss: 0.01745 |  0:00:48s
# epoch 34 | loss: 0.01636 | val_0_val_loss: 0.01763 |  0:00:49s
# epoch 35 | loss: 0.01641 | val_0_val_loss: 0.0202  |  0:00:50s
# epoch 36 | loss: 0.01637 | val_0_val_loss: 0.01745 |  0:00:52s
# epoch 37 | loss: 0.01624 | val_0_val_loss: 0.01736 |  0:00:53s
# epoch 38 | loss: 0.0162  | val_0_val_loss: 0.01849 |  0:00:55s
# epoch 39 | loss: 0.0162  | val_0_val_loss: 0.01728 |  0:00:56s
# epoch 40 | loss: 0.0161  | val_0_val_loss: 0.01798 |  0:00:57s
# epoch 41 | loss: 0.01612 | val_0_val_loss: 0.02087 |  0:00:58s
# epoch 42 | loss: 0.01597 | val_0_val_loss: 0.01701 |  0:01:00s
# epoch 43 | loss: 0.01595 | val_0_val_loss: 0.01747 |  0:01:01s
# epoch 44 | loss: 0.01593 | val_0_val_loss: 0.01838 |  0:01:03s
# epoch 45 | loss: 0.01591 | val_0_val_loss: 0.01732 |  0:01:04s
# epoch 46 | loss: 0.01599 | val_0_val_loss: 0.01807 |  0:01:06s
# epoch 47 | loss: 0.01599 | val_0_val_loss: 0.01785 |  0:01:07s
# epoch 48 | loss: 0.01587 | val_0_val_loss: 0.017   |  0:01:09s
# epoch 49 | loss: 0.01598 | val_0_val_loss: 0.01775 |  0:01:10s
# epoch 50 | loss: 0.0159  | val_0_val_loss: 0.0168  |  0:01:11s
# epoch 51 | loss: 0.01577 | val_0_val_loss: 0.01684 |  0:01:13s
# epoch 52 | loss: 0.01572 | val_0_val_loss: 0.0169  |  0:01:14s
# epoch 53 | loss: 0.01564 | val_0_val_loss: 0.01695 |  0:01:16s
# epoch 54 | loss: 0.01563 | val_0_val_loss: 0.01698 |  0:01:17s
# epoch 55 | loss: 0.01566 | val_0_val_loss: 0.01678 |  0:01:18s
# epoch 56 | loss: 0.01567 | val_0_val_loss: 0.01843 |  0:01:20s
# epoch 57 | loss: 0.01568 | val_0_val_loss: 0.01694 |  0:01:21s
# epoch 58 | loss: 0.01552 | val_0_val_loss: 0.01714 |  0:01:22s
# epoch 59 | loss: 0.01549 | val_0_val_loss: 0.01708 |  0:01:24s
# epoch 60 | loss: 0.01547 | val_0_val_loss: 0.0168  |  0:01:25s
# epoch 61 | loss: 0.01555 | val_0_val_loss: 0.01695 |  0:01:27s
# epoch 62 | loss: 0.0155  | val_0_val_loss: 0.01698 |  0:01:28s
# epoch 63 | loss: 0.01563 | val_0_val_loss: 0.01708 |  0:01:30s
# epoch 64 | loss: 0.01556 | val_0_val_loss: 0.01684 |  0:01:31s
# epoch 65 | loss: 0.01554 | val_0_val_loss: 0.01723 |  0:01:32s
#
# Early stopping occured at epoch 65 with best_epoch = 55 and best_val_0_val_loss = 0.01678
# Best weights from best epoch are automatically used!
# FOLD:  10
# Device used : cuda
# epoch 0  | loss: 0.39498 | val_0_val_loss: 0.05735 |  0:00:01s
# epoch 1  | loss: 0.0289  | val_0_val_loss: 0.02705 |  0:00:02s
# epoch 2  | loss: 0.02293 | val_0_val_loss: 0.02217 |  0:00:03s
# epoch 3  | loss: 0.02131 | val_0_val_loss: 0.021   |  0:00:05s
# epoch 4  | loss: 0.02085 | val_0_val_loss: 0.02067 |  0:00:06s
# epoch 5  | loss: 0.02061 | val_0_val_loss: 0.02048 |  0:00:08s
# epoch 6  | loss: 0.02039 | val_0_val_loss: 0.02043 |  0:00:09s
# epoch 7  | loss: 0.02024 | val_0_val_loss: 0.02114 |  0:00:11s
# epoch 8  | loss: 0.02002 | val_0_val_loss: 0.02003 |  0:00:12s
# epoch 9  | loss: 0.0197  | val_0_val_loss: 0.0196  |  0:00:14s
# epoch 10 | loss: 0.01931 | val_0_val_loss: 0.01927 |  0:00:15s
# epoch 11 | loss: 0.01897 | val_0_val_loss: 0.01902 |  0:00:16s
# epoch 12 | loss: 0.01876 | val_0_val_loss: 0.01906 |  0:00:18s
# epoch 13 | loss: 0.01852 | val_0_val_loss: 0.01876 |  0:00:19s
# epoch 14 | loss: 0.01831 | val_0_val_loss: 0.01845 |  0:00:21s
# epoch 15 | loss: 0.01814 | val_0_val_loss: 0.01855 |  0:00:22s
# epoch 16 | loss: 0.01787 | val_0_val_loss: 0.01871 |  0:00:23s
# epoch 17 | loss: 0.01775 | val_0_val_loss: 0.01889 |  0:00:25s
# epoch 18 | loss: 0.01754 | val_0_val_loss: 0.01813 |  0:00:26s
# epoch 19 | loss: 0.01741 | val_0_val_loss: 0.01805 |  0:00:27s
# epoch 20 | loss: 0.01728 | val_0_val_loss: 0.01787 |  0:00:29s
# epoch 21 | loss: 0.01727 | val_0_val_loss: 0.01791 |  0:00:30s
# epoch 22 | loss: 0.01711 | val_0_val_loss: 0.0182  |  0:00:32s
# epoch 23 | loss: 0.01696 | val_0_val_loss: 0.01785 |  0:00:33s
# epoch 24 | loss: 0.01695 | val_0_val_loss: 0.02035 |  0:00:35s
# epoch 25 | loss: 0.0169  | val_0_val_loss: 0.01957 |  0:00:36s
# epoch 26 | loss: 0.01673 | val_0_val_loss: 0.01775 |  0:00:37s
# epoch 27 | loss: 0.01671 | val_0_val_loss: 0.02031 |  0:00:39s
# epoch 28 | loss: 0.0166  | val_0_val_loss: 0.01782 |  0:00:40s
# epoch 29 | loss: 0.0165  | val_0_val_loss: 0.01982 |  0:00:41s
# epoch 30 | loss: 0.01644 | val_0_val_loss: 0.01755 |  0:00:43s
# epoch 31 | loss: 0.01644 | val_0_val_loss: 0.0185  |  0:00:44s
# epoch 32 | loss: 0.01644 | val_0_val_loss: 0.02062 |  0:00:46s
# epoch 33 | loss: 0.01624 | val_0_val_loss: 0.01791 |  0:00:47s
# epoch 34 | loss: 0.01622 | val_0_val_loss: 0.02001 |  0:00:48s
# epoch 35 | loss: 0.01619 | val_0_val_loss: 0.01871 |  0:00:50s
# epoch 36 | loss: 0.01621 | val_0_val_loss: 0.02099 |  0:00:51s
# epoch 37 | loss: 0.01617 | val_0_val_loss: 0.01845 |  0:00:52s
# epoch 38 | loss: 0.0162  | val_0_val_loss: 0.01803 |  0:00:54s
# epoch 39 | loss: 0.01611 | val_0_val_loss: 0.01792 |  0:00:55s
# epoch 40 | loss: 0.01596 | val_0_val_loss: 0.01848 |  0:00:56s
#
# Early stopping occured at epoch 40 with best_epoch = 30 and best_val_0_val_loss = 0.01755
# Best weights from best epoch are automatically used!

# %%
pred_mean = np.mean(pred_encode, axis = 0)
# take a copy of all our training sig_ids for reference
test_sig_ids = test_features['sig_id'].copy()

# select all indices when 'cp_type' is 'ctl_vehicle'
test_ctl_vehicle_idx = (test_features['cp_type'] == 'ctl_vehicle')

# change all cp_type == ctl_vehicle predictions to zero
pred_mean[test_sig_ids[test_ctl_vehicle_idx].index.values] = 0
test_submission = pd.DataFrame({'sig_id' : test_sig_ids})
test_preds_df = pd.DataFrame(pred_mean, columns=train_targets_scored.columns[1:])
test_submission = pd.concat([test_submission, test_preds_df], axis=1)
test_submission.head(3)
# Out:
#          sig_id  5-alpha_reductase_inhibitor  11-beta-hsd1_inhibitor  \
# 0  id_0004d9e33                     0.000958                0.000903
# 1  id_001897cda                     0.000891                0.001052
# 2  id_002429b5b                     0.000000                0.000000
#
#    acat_inhibitor  acetylcholine_receptor_agonist  \
# 0        0.001403                        0.007455
# 1        0.001741                        0.009358
# 2        0.000000                        0.000000
#
#    acetylcholine_receptor_antagonist  acetylcholinesterase_inhibitor  \
# 0                           0.014341                        0.003101
# 1                           0.012656                        0.003759
# 2                           0.000000                        0.000000
#
#    adenosine_receptor_agonist  adenosine_receptor_antagonist  \
# 0                    0.002029                       0.005461
# 1                    0.002646                       0.004528
# 2                    0.000000                       0.000000
#
#    adenylyl_cyclase_activator  ...  tropomyosin_receptor_kinase_inhibitor  \
# 0                    0.000422  ...                               0.000544
# 1                    0.001849  ...                               0.000677
# 2                    0.000000  ...                               0.000000
#
#    trpv_agonist  trpv_antagonist  tubulin_inhibitor  \
# 0      0.000959         0.001637           0.095493
# 1      0.000977         0.002123           0.002072
# 2      0.000000         0.000000           0.000000
#
#    tyrosine_kinase_inhibitor  ubiquitin_specific_protease_inhibitor  \
# 0                   0.002780                               0.000554
# 1                   0.002038                               0.000644
# 2                   0.000000                               0.000000
#
#    vegfr_inhibitor  vitamin_b  vitamin_d_receptor_agonist  wnt_inhibitor
# 0         0.002451   0.001590                    0.001579       0.001294
# 1         0.001265   0.001665                    0.001365       0.001814
# 2         0.000000   0.000000                    0.000000       0.000000
#
# [3 rows x 207 columns]

# %%
test_submission.to_csv('submission.csv', index=False)
